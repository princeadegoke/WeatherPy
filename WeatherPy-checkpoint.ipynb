# %% [markdown]
# # WeatherPy

# %% [markdown]
# # Analysis:
#     - The temperature charts shows the relationship between the latitude and the degree of temperature
#     which is inversely related.
#     - The humidity is high as the latitude increases in its axis,it is necessary to understand vapour pressure and in particular the gaseous nature of water vapour.
#     -The latitude and Cloudness shows that vapour also affects the weather because, as indicated below, it condenses into clouds and falls as rain or other forms of precipitation.
#     - The lower the speed of wind in the higher latitude the more concentration of of water vapour inin the atmosphere.The basic relationship between atmospheric pressure and horizontal wind is revealed by disregarding friction and any changes in wind direction and speed.

# %%
# Dependencies
import random
import requests as req

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from citipy import citipy

import openweathermapy as owm

#To get the current date
import datetime
now = datetime.datetime.now()

# %% [markdown]
# Generate Cities List:

# %%
# Create a settings object with your API key and preferred units
api_key = "2092f20a9cc5d2c19008fc62765c923e"
# Setting the units to imperial to get Fahrenheit reading
settings = {"units": "imperial", "appid": api_key}

# %% [markdown]
# Perform API Calls:

# %%
# Latitude ranges from -90 to 90 and Longitude ranges from -180 to 180
lat = list(np.arange(-90,90.01,0.01))
long = list(np.arange(-180,180.01,0.01))

# Setting Latitude and Longitude to ramdomly pick co-ordinates.
lat_samples=random.sample(lat,2500)
long_samples=random.sample(long,2500)

# Creating a dataframe from the randomly sample Latitude and Longitude
cities_df=pd.DataFrame({"Latitude":lat_samples,"Longitude":long_samples})

#Creating new columns City and Country for storing the details corresponding to the co-ordinates
cities_df["City"]=""
cities_df["Country"]=""

# Finding the city and the country code corresponding to the Latitude and Longitude
for index,row in cities_df.iterrows():
    city=citipy.nearest_city(row["Latitude"], row["Longitude"])
    cities_df.set_value(index, "City", city.city_name)
    cities_df.set_value(index, "Country", city.country_code)

# Dropping the Latitude and Longitude as they are values of the nearest city and not the excat co-ordinates of the city
cities_df=cities_df.drop(cities_df.columns[[0, 1]], axis=1)

# Deleting duplicate values from the list of cities and keeping only the first
cities_df=cities_df.drop_duplicates(['City'], keep='first')

# Randomly sampling a list of 800 cities 
cities_df=cities_df.sample(n=800)

# Resetting the index of the cities list
cities_df=cities_df.reset_index(drop=True)

cities_df.head()
# Out:
#           City Country
# 0     hanzhong      cn
# 1       jiexiu      cn
# 2      dauriya      ru
# 3  henties bay      na
# 4      jaragua      br

# %%
# Get data for each city in cities_df
weather_data = []

url="https://api.openweathermap.org/data/2.5/weather?appid=" + api_key + "&units=imperial&q="

print("\nStats Data Minning\n-----------------------------")
#Get the response from OpenWeatherMapY and storing the response into weather_data if response is found
for index,row in cities_df.iterrows():  
    print("\nProcessing record %s|%s,%s"%((index+1),row["City"],row["Country"]))
    print("\n"+url+"%s,%s"%(row["City"].replace(" ","+"),row["Country"]))
    try:
        response = owm.get_current("%s,%s"%(row["City"],row["Country"]), **settings)
        # Appending the response to the weather_Data
        weather_data.append(response)
    except:
        print("\n\033[1;31mCity not found. Skipping...\033[1;30m")

print("\n-----------------------------\nData Minning Completed\n-----------------------------")
# Out:
# Stats Data Minning
# -----------------------------
#
# Processing record 1|hanzhong,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hanzhong,cn
#
# Processing record 2|jiexiu,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=jiexiu,cn
#
# Processing record 3|dauriya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dauriya,ru
#
# Processing record 4|henties bay,na
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=henties+bay,na
#
# Processing record 5|jaragua,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=jaragua,br
#
# Processing record 6|sorvag,fo
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sorvag,fo
#
# City not found. Skipping...
#
# Processing record 7|allapalli,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=allapalli,in
#
# Processing record 8|atamanovka,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=atamanovka,ru
#
# Processing record 9|hearst,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hearst,ca
#
# Processing record 10|gorontalo,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=gorontalo,id
#
# Processing record 11|kailua,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kailua,us
#
# Processing record 12|los llanos de aridane,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=los+llanos+de+aridane,es
#
# Processing record 13|tasiilaq,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tasiilaq,gl
#
# Processing record 14|coburg,de
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=coburg,de
#
# Processing record 15|malmesbury,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=malmesbury,za
#
# Processing record 16|kupang,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kupang,id
#
# Processing record 17|madaoua,ne
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=madaoua,ne
#
# Processing record 18|felidhoo,mv
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=felidhoo,mv
#
# City not found. Skipping...
#
# Processing record 19|faanui,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=faanui,pf
#
# Processing record 20|kiama,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kiama,au
#
# Processing record 21|marsh harbour,bs
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=marsh+harbour,bs
#
# Processing record 22|shenzhen,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=shenzhen,cn
#
# Processing record 23|mocuba,mz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mocuba,mz
#
# Processing record 24|asayita,et
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=asayita,et
#
# City not found. Skipping...
#
# Processing record 25|kaeo,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kaeo,nz
#
# Processing record 26|veracruz,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=veracruz,mx
#
# Processing record 27|boende,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=boende,cd
#
# Processing record 28|sao jose da coroa grande,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sao+jose+da+coroa+grande,br
#
# Processing record 29|tessalit,ml
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tessalit,ml
#
# Processing record 30|axim,gh
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=axim,gh
#
# Processing record 31|tambovka,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tambovka,ru
#
# Processing record 32|ushtobe,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ushtobe,kz
#
# Processing record 33|biltine,td
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=biltine,td
#
# Processing record 34|antsohihy,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=antsohihy,mg
#
# Processing record 35|srednekolymsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=srednekolymsk,ru
#
# Processing record 36|adrar,dz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=adrar,dz
#
# Processing record 37|tall kayf,iq
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tall+kayf,iq
#
# City not found. Skipping...
#
# Processing record 38|charkhi dadri,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=charkhi+dadri,in
#
# Processing record 39|beaverlodge,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=beaverlodge,ca
#
# Processing record 40|krasnoselkup,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=krasnoselkup,ru
#
# City not found. Skipping...
#
# Processing record 41|soller,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=soller,es
#
# Processing record 42|taormina,it
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=taormina,it
#
# Processing record 43|kahului,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kahului,us
#
# Processing record 44|fortuna,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fortuna,us
#
# Processing record 45|nador,ma
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nador,ma
#
# Processing record 46|hibbing,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hibbing,us
#
# Processing record 47|puerto ayacucho,ve
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=puerto+ayacucho,ve
#
# Processing record 48|astoria,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=astoria,us
#
# Processing record 49|bonavista,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bonavista,ca
#
# Processing record 50|spearfish,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=spearfish,us
#
# Processing record 51|denpasar,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=denpasar,id
#
# Processing record 52|yulara,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=yulara,au
#
# Processing record 53|sentyabrskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sentyabrskiy,ru
# City not found. Skipping...
#
# Processing record 54|vostok,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=vostok,ru
#
# Processing record 55|luderitz,na
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=luderitz,na
#
# Processing record 56|madras,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=madras,in
#
# City not found. Skipping...
#
# Processing record 57|carbonear,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=carbonear,ca
#
# Processing record 58|avarua,ck
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=avarua,ck
#
# Processing record 59|pisco,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pisco,pe
#
# Processing record 60|lolua,tv
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lolua,tv
#
# City not found. Skipping...
#
# Processing record 61|beroroha,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=beroroha,mg
#
# Processing record 62|banda aceh,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=banda+aceh,id
#
# Processing record 63|korla,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=korla,cn
#
# Processing record 64|barrow,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=barrow,us
#
# Processing record 65|nikolskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nikolskoye,ru
#
# Processing record 66|galveston,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=galveston,us
#
# Processing record 67|ilebo,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ilebo,cd
#
# Processing record 68|aksu,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=aksu,cn
#
# Processing record 69|mozhga,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mozhga,ru
#
# Processing record 70|lyuban,by
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lyuban,by
#
# Processing record 71|susangerd,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=susangerd,ir
#
# Processing record 72|abadan,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=abadan,ir
#
# Processing record 73|bhalki,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bhalki,in
#
# Processing record 74|los andes,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=los+andes,cl
#
# Processing record 75|irbeyskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=irbeyskoye,ru
#
# Processing record 76|bengkulu,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bengkulu,id
#
# City not found. Skipping...
#
# Processing record 77|airai,pw
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=airai,pw
#
# City not found. Skipping...
#
# Processing record 78|lavrentiya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lavrentiya,ru
#
# Processing record 79|aasiaat,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=aasiaat,gl
#
# Processing record 80|watsa,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=watsa,cd
#
# Processing record 81|preobrazheniye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=preobrazheniye,ru
#
# Processing record 82|marzuq,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=marzuq,ly
#
# City not found. Skipping...
#
# Processing record 83|agadez,ne
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=agadez,ne
#
# Processing record 84|cayenne,gf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=cayenne,gf
#
# Processing record 85|emilio carranza,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=emilio+carranza,mx
#
# Processing record 86|dom pedrito,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dom+pedrito,br
#
# Processing record 87|asau,tv
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=asau,tv
#
# City not found. Skipping...
#
# Processing record 88|alta floresta,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=alta+floresta,br
#
# Processing record 89|puerto del rosario,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=puerto+del+rosario,es
#
# Processing record 90|moussoro,td
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=moussoro,td
#
# Processing record 91|naze,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=naze,jp
#
# Processing record 92|kotelniki,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kotelniki,ru
#
# Processing record 93|jamestown,sh
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=jamestown,sh
#
# Processing record 94|pangody,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pangody,ru
#
# Processing record 95|havre-saint-pierre,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=havre-saint-pierre,ca
#
# Processing record 96|ribeira brava,cv
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ribeira+brava,cv
#
# City not found. Skipping...
#
# Processing record 97|murud,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=murud,in
#
# City not found. Skipping...
#
# Processing record 98|victoria,sc
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=victoria,sc
#
# Processing record 99|clyde river,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=clyde+river,ca
#
# Processing record 100|ancud,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ancud,cl
#
# Processing record 101|vaini,to
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=vaini,to
#
# Processing record 102|codrington,ag
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=codrington,ag
#
# City not found. Skipping...
#
# Processing record 103|arara,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=arara,br
#
# Processing record 104|jumla,np
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=jumla,np
#
# Processing record 105|jiangyou,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=jiangyou,cn
# Processing record 106|springbok,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=springbok,za
#
# Processing record 107|amderma,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=amderma,ru
#
# City not found. Skipping...
#
# Processing record 108|villa maria,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=villa+maria,ar
#
# Processing record 109|bathsheba,bb
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bathsheba,bb
#
# Processing record 110|sawakin,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sawakin,sd
#
# Processing record 111|kouroussa,gn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kouroussa,gn
#
# Processing record 112|tarko-sale,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tarko-sale,ru
#
# Processing record 113|rehoboth,na
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rehoboth,na
#
# Processing record 114|bahir dar,et
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bahir+dar,et
#
# Processing record 115|kutum,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kutum,sd
#
# Processing record 116|fujin,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fujin,cn
#
# Processing record 117|san cristobal,ec
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=san+cristobal,ec
#
# Processing record 118|tiksi,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tiksi,ru
#
# Processing record 119|urdzhar,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=urdzhar,kz
#
# City not found. Skipping...
#
# Processing record 120|sijunjung,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sijunjung,id
#
# Processing record 121|aykhal,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=aykhal,ru
#
# Processing record 122|bathurst,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bathurst,ca
#
# Processing record 123|lincoln,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lincoln,us
#
# Processing record 124|narsaq,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=narsaq,gl
#
# Processing record 125|grand gaube,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=grand+gaube,mu
#
# Processing record 126|ihosy,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ihosy,mg
#
# Processing record 127|risod,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=risod,in
#
# Processing record 128|kamaishi,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kamaishi,jp
#
# Processing record 129|sola,vu
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sola,vu
#
# Processing record 130|guanambi,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=guanambi,br
#
# Processing record 131|leningradskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=leningradskiy,ru
#
# Processing record 132|san jeronimo,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=san+jeronimo,mx
#
# Processing record 133|syamzha,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=syamzha,ru
#
# Processing record 134|beloha,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=beloha,mg
#
# Processing record 135|college,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=college,us
#
# Processing record 136|kavaratti,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kavaratti,in
#
# Processing record 137|phalaborwa,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=phalaborwa,za
#
# Processing record 138|roma,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=roma,au
#
# Processing record 139|santa barbara,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=santa+barbara,mx
#
# Processing record 140|voh,nc
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=voh,nc
#
# Processing record 141|mookane,bw
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mookane,bw
#
# Processing record 142|lianzhou,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lianzhou,cn
#
# Processing record 143|stornoway,gb
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=stornoway,gb
#
# Processing record 144|high level,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=high+level,ca
#
# Processing record 145|katsuura,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=katsuura,jp
#
# Processing record 146|kaifeng,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kaifeng,cn
#
# Processing record 147|oktyabrskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=oktyabrskoye,ru
#
# Processing record 148|ukiah,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ukiah,us
#
# Processing record 149|wewak,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=wewak,pg
#
# Processing record 150|piacabucu,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=piacabucu,br
#
# Processing record 151|manicore,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=manicore,br
#
# Processing record 152|champerico,gt
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=champerico,gt
#
# Processing record 153|rocha,uy
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rocha,uy
#
# Processing record 154|maghama,mr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=maghama,mr
#
# City not found. Skipping...
#
# Processing record 155|rio grande,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rio+grande,br
#
# Processing record 156|punta arenas,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=punta+arenas,cl
#
# Processing record 157|indiana,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=indiana,us
#
# Processing record 158|kuito,ao
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kuito,ao
#
# Processing record 159|espanola,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=espanola,ca
# Processing record 160|kysyl-syr,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kysyl-syr,ru
#
# Processing record 161|pudozh,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pudozh,ru
#
# Processing record 162|ha giang,vn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ha+giang,vn
#
# Processing record 163|methoni,gr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=methoni,gr
#
# Processing record 164|claresholm,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=claresholm,ca
#
# Processing record 165|peleduy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=peleduy,ru
#
# Processing record 166|yaan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=yaan,cn
#
# City not found. Skipping...
#
# Processing record 167|susehri,tr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=susehri,tr
#
# Processing record 168|coahuayana,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=coahuayana,mx
#
# Processing record 169|tommot,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tommot,ru
#
# Processing record 170|puerto carreno,co
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=puerto+carreno,co
#
# Processing record 171|biga,tr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=biga,tr
#
# Processing record 172|gao,ml
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=gao,ml
#
# Processing record 173|tonj,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tonj,sd
#
# City not found. Skipping...
#
# Processing record 174|palora,ec
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=palora,ec
#
# Processing record 175|garden city,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=garden+city,us
#
# Processing record 176|meulaboh,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=meulaboh,id
#
# Processing record 177|vao,nc
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=vao,nc
#
# Processing record 178|gushikawa,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=gushikawa,jp
#
# Processing record 179|urubicha,bo
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=urubicha,bo
#
# Processing record 180|dalinghe,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dalinghe,cn
#
# City not found. Skipping...
#
# Processing record 181|khingansk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=khingansk,ru
#
# Processing record 182|ewa beach,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ewa+beach,us
#
# Processing record 183|ust-tsilma,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ust-tsilma,ru
#
# Processing record 184|beisfjord,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=beisfjord,no
#
# Processing record 185|mahebourg,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mahebourg,mu
#
# Processing record 186|lawrenceburg,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lawrenceburg,us
#
# Processing record 187|hastings,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hastings,us
#
# Processing record 188|tilichiki,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tilichiki,ru
#
# Processing record 189|liverpool,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=liverpool,ca
#
# Processing record 190|kerteh,my
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kerteh,my
#
# City not found. Skipping...
#
# Processing record 191|waitara,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=waitara,nz
#
# Processing record 192|kemijarvi,fi
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kemijarvi,fi
#
# City not found. Skipping...
#
# Processing record 193|fethiye,tr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fethiye,tr
#
# Processing record 194|aklavik,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=aklavik,ca
#
# Processing record 195|mana,gf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mana,gf
#
# Processing record 196|chala,tz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=chala,tz
#
# Processing record 197|rosarito,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rosarito,mx
#
# Processing record 198|brandenburg,de
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=brandenburg,de
#
# Processing record 199|labutta,mm
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=labutta,mm
#
# City not found. Skipping...
#
# Processing record 200|waddan,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=waddan,ly
#
# Processing record 201|pinega,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pinega,ru
#
# Processing record 202|urengoy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=urengoy,ru
#
# Processing record 203|sao filipe,cv
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sao+filipe,cv
#
# Processing record 204|dikson,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dikson,ru
#
# Processing record 205|vila franca do campo,pt
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=vila+franca+do+campo,pt
#
# Processing record 206|petropavlovsk-kamchatskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=petropavlovsk-kamchatskiy,ru
#
# Processing record 207|nelson bay,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nelson+bay,au
#
# Processing record 208|hermanus,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hermanus,za
#
# Processing record 209|pitimbu,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pitimbu,br
#
# Processing record 210|mount gambier,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mount+gambier,au
#
# Processing record 211|kodiak,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kodiak,us
#
# Processing record 212|raga,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=raga,sd
# City not found. Skipping...
#
# Processing record 213|manger,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=manger,no
#
# Processing record 214|gotsu,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=gotsu,jp
#
# Processing record 215|provideniya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=provideniya,ru
#
# Processing record 216|caapucu,py
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=caapucu,py
#
# Processing record 217|san juan,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=san+juan,ar
#
# Processing record 218|nemuro,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nemuro,jp
#
# Processing record 219|busselton,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=busselton,au
#
# Processing record 220|te anau,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=te+anau,nz
#
# Processing record 221|rolleston,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rolleston,nz
#
# Processing record 222|yumen,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=yumen,cn
#
# Processing record 223|lat yao,th
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lat+yao,th
#
# Processing record 224|svetlaya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=svetlaya,ru
#
# Processing record 225|yatou,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=yatou,cn
#
# Processing record 226|hofn,is
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hofn,is
#
# Processing record 227|dudinka,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dudinka,ru
#
# Processing record 228|barra do garcas,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=barra+do+garcas,br
#
# Processing record 229|samusu,ws
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=samusu,ws
#
# City not found. Skipping...
#
# Processing record 230|roura,gf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=roura,gf
#
# Processing record 231|port hardy,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=port+hardy,ca
#
# Processing record 232|shelburne,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=shelburne,ca
#
# Processing record 233|sechura,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sechura,pe
#
# Processing record 234|baghdad,iq
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=baghdad,iq
#
# Processing record 235|butaritari,ki
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=butaritari,ki
#
# Processing record 236|fengzhen,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fengzhen,cn
#
# Processing record 237|tsarychanka,ua
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tsarychanka,ua
#
# Processing record 238|rosita,ni
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rosita,ni
#
# Processing record 239|nouadhibou,mr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nouadhibou,mr
#
# Processing record 240|greece,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=greece,us
#
# Processing record 241|ust-omchug,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ust-omchug,ru
#
# Processing record 242|mayumba,ga
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mayumba,ga
#
# Processing record 243|necochea,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=necochea,ar
#
# Processing record 244|klaksvik,fo
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=klaksvik,fo
#
# Processing record 245|balimo,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=balimo,pg
#
# City not found. Skipping...
#
# Processing record 246|east london,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=east+london,za
#
# Processing record 247|longyearbyen,sj
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=longyearbyen,sj
#
# Processing record 248|marcona,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=marcona,pe
#
# City not found. Skipping...
#
# Processing record 249|arraial do cabo,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=arraial+do+cabo,br
#
# Processing record 250|berja,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=berja,es
#
# Processing record 251|caloundra,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=caloundra,au
#
# Processing record 252|huicheng,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=huicheng,cn
#
# Processing record 253|dharchula,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dharchula,in
#
# Processing record 254|sinnamary,gf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sinnamary,gf
#
# Processing record 255|sulina,ro
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sulina,ro
#
# Processing record 256|alyangula,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=alyangula,au
#
# Processing record 257|snyder,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=snyder,us
#
# Processing record 258|maceio,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=maceio,br
#
# Processing record 259|rawson,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rawson,ar
#
# Processing record 260|paveh,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=paveh,ir
#
# Processing record 261|port lavaca,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=port+lavaca,us
#
# Processing record 262|tumannyy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tumannyy,ru
#
# City not found. Skipping...
#
# Processing record 263|tuktoyaktuk,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tuktoyaktuk,ca
#
# Processing record 264|hithadhoo,mv
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hithadhoo,mv
#
# Processing record 265|bandundu,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bandundu,cd
# Processing record 266|skalistyy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=skalistyy,ru
#
# City not found. Skipping...
#
# Processing record 267|onega,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=onega,ru
#
# Processing record 268|padang,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=padang,id
#
# Processing record 269|nizhneyansk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nizhneyansk,ru
#
# City not found. Skipping...
#
# Processing record 270|loei,th
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=loei,th
#
# Processing record 271|baculin,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=baculin,ph
#
# Processing record 272|lyubeshiv,ua
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lyubeshiv,ua
#
# City not found. Skipping...
#
# Processing record 273|lieto,fi
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lieto,fi
#
# Processing record 274|sorland,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sorland,no
#
# Processing record 275|ayan,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ayan,ru
#
# City not found. Skipping...
#
# Processing record 276|bam,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bam,ir
#
# Processing record 277|portobelo,pa
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=portobelo,pa
#
# Processing record 278|copiapo,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=copiapo,cl
#
# Processing record 279|uvarovo,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=uvarovo,ru
#
# Processing record 280|beringovskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=beringovskiy,ru
#
# Processing record 281|san miguel,pa
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=san+miguel,pa
#
# Processing record 282|havoysund,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=havoysund,no
#
# Processing record 283|jalu,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=jalu,ly
#
# Processing record 284|darab,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=darab,ir
#
# Processing record 285|homer,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=homer,us
#
# Processing record 286|diego de almagro,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=diego+de+almagro,cl
#
# Processing record 287|cadca,sk
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=cadca,sk
#
# Processing record 288|isla vista,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=isla+vista,us
#
# Processing record 289|juneau,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=juneau,us
#
# Processing record 290|kapit,my
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kapit,my
#
# Processing record 291|aitape,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=aitape,pg
#
# Processing record 292|palabuhanratu,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=palabuhanratu,id
#
# City not found. Skipping...
#
# Processing record 293|vallenar,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=vallenar,cl
#
# Processing record 294|den helder,nl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=den+helder,nl
#
# Processing record 295|pasni,pk
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pasni,pk
#
# Processing record 296|boras,se
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=boras,se
#
# Processing record 297|ust-kulom,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ust-kulom,ru
#
# Processing record 298|grand river south east,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=grand+river+south+east,mu
#
# City not found. Skipping...
#
# Processing record 299|kitimat,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kitimat,ca
#
# Processing record 300|touros,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=touros,br
#
# Processing record 301|port keats,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=port+keats,au
#
# Processing record 302|guerrero negro,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=guerrero+negro,mx
#
# Processing record 303|yacuiba,bo
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=yacuiba,bo
#
# Processing record 304|idrinskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=idrinskoye,ru
#
# Processing record 305|evensk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=evensk,ru
#
# Processing record 306|oussouye,sn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=oussouye,sn
#
# Processing record 307|veraval,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=veraval,in
#
# Processing record 308|malwan,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=malwan,in
#
# City not found. Skipping...
#
# Processing record 309|tocopilla,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tocopilla,cl
#
# ...
#
# Processing record 699|narsipatnam,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=narsipatnam,in
#
# Processing record 700|ust-nera,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ust-nera,ru
#
# Processing record 701|brae,gb
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=brae,gb
#
# Processing record 702|seddon,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=seddon,nz
#
# Processing record 703|nantucket,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nantucket,us
#
# Processing record 704|alugan,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=alugan,ph
#
# Processing record 705|taolanaro,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=taolanaro,mg
#
# City not found. Skipping...
#
# Processing record 706|tutoia,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tutoia,br
#
# Processing record 707|lompoc,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lompoc,us
#
# Processing record 708|mataura,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mataura,pf
#
# City not found. Skipping...
#
# Processing record 709|mizdah,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mizdah,ly
#
# Processing record 710|vung tau,vn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=vung+tau,vn
#
# Processing record 711|tautira,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tautira,pf
#
# Processing record 712|diffa,ne
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=diffa,ne
#
# Processing record 713|saint-pierre,pm
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=saint-pierre,pm
#
# Processing record 714|coquimbo,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=coquimbo,cl
#
# Processing record 715|sochi,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sochi,ru
#
# Processing record 716|geraldton,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=geraldton,au
#
# Processing record 717|paamiut,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=paamiut,gl
#
# Processing record 718|atuona,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=atuona,pf
#
# Processing record 719|beira,mz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=beira,mz
#
# Processing record 720|pacific grove,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pacific+grove,us
#
# Processing record 721|pangnirtung,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pangnirtung,ca
#
# Processing record 722|cordoba,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=cordoba,ar
#
# Processing record 723|ndjole,ga
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ndjole,ga
#
# Processing record 724|yar-sale,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=yar-sale,ru
#
# Processing record 725|umm bab,qa
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=umm+bab,qa
#
# Processing record 726|dese,et
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dese,et
#
# Processing record 727|borkenes,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=borkenes,no
#
# Processing record 728|santiago del estero,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=santiago+del+estero,ar
#
# Processing record 729|marsaxlokk,mt
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=marsaxlokk,mt
#
# Processing record 730|hasaki,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hasaki,jp
#
# Processing record 731|ano mera,gr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ano+mera,gr
#
# Processing record 732|chimbote,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=chimbote,pe
#
# Processing record 733|calvia,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=calvia,es
#
# Processing record 734|luau,ao
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=luau,ao
#
# Processing record 735|robertsport,lr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=robertsport,lr
#
# Processing record 736|kalabo,zm
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kalabo,zm
#
# Processing record 737|muros,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=muros,es
#
# Processing record 738|mouzakion,gr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mouzakion,gr
#
# City not found. Skipping...
#
# Processing record 739|pangai,to
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pangai,to
# Processing record 740|talnakh,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=talnakh,ru
#
# Processing record 741|redlands,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=redlands,us
#
# Processing record 742|klyuchi,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=klyuchi,ru
#
# Processing record 743|barao de melgaco,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=barao+de+melgaco,br
#
# Processing record 744|belogorsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=belogorsk,ru
#
# Processing record 745|southbridge,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=southbridge,nz
#
# Processing record 746|saint-augustin,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=saint-augustin,ca
#
# Processing record 747|bambous virieux,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bambous+virieux,mu
#
# Processing record 748|tuatapere,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tuatapere,nz
#
# Processing record 749|wajima,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=wajima,jp
#
# Processing record 750|miranorte,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=miranorte,br
#
# City not found. Skipping...
#
# Processing record 751|naryan-mar,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=naryan-mar,ru
#
# Processing record 752|tianpeng,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tianpeng,cn
#
# Processing record 753|kushima,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kushima,jp
#
# Processing record 754|santa ana,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=santa+ana,pe
#
# Processing record 755|bambanglipuro,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bambanglipuro,id
#
# Processing record 756|souillac,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=souillac,mu
#
# Processing record 757|eldikan,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=eldikan,ru
#
# City not found. Skipping...
#
# Processing record 758|cumaribo,co
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=cumaribo,co
#
# City not found. Skipping...
#
# Processing record 759|ballarat,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ballarat,au
#
# Processing record 760|oliver,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=oliver,ca
#
# Processing record 761|pevek,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pevek,ru
#
# Processing record 762|port alfred,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=port+alfred,za
#
# Processing record 763|muswellbrook,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=muswellbrook,au
#
# Processing record 764|bredasdorp,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bredasdorp,za
#
# Processing record 765|praia,cv
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=praia,cv
#
# Processing record 766|chagda,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=chagda,ru
#
# City not found. Skipping...
#
# Processing record 767|gornopravdinsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=gornopravdinsk,ru
#
# Processing record 768|komsomolskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=komsomolskiy,ru
#
# Processing record 769|nampula,mz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nampula,mz
#
# Processing record 770|basco,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=basco,ph
#
# Processing record 771|chapais,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=chapais,ca
#
# Processing record 772|kesinga,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kesinga,in
#
# Processing record 773|broager,dk
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=broager,dk
#
# Processing record 774|karkaralinsk,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=karkaralinsk,kz
#
# City not found. Skipping...
#
# Processing record 775|linxia,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=linxia,cn
#
# Processing record 776|dalbandin,pk
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dalbandin,pk
#
# Processing record 777|porto novo,cv
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=porto+novo,cv
#
# Processing record 778|san patricio,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=san+patricio,mx
#
# Processing record 779|pushkar,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pushkar,in
#
# Processing record 780|kuningan,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kuningan,id
#
# Processing record 781|xudat,az
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=xudat,az
#
# Processing record 782|toliary,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=toliary,mg
#
# City not found. Skipping...
#
# Processing record 783|mamakan,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mamakan,ru
#
# Processing record 784|labuhan,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=labuhan,id
#
# Processing record 785|san carlos,ve
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=san+carlos,ve
#
# Processing record 786|coolum beach,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=coolum+beach,au
#
# Processing record 787|sibu,my
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sibu,my
#
# Processing record 788|dalby,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dalby,au
#
# Processing record 789|bulalacao,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bulalacao,ph
#
# Processing record 790|kungurtug,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kungurtug,ru
#
# Processing record 791|capaci,it
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=capaci,it
# Processing record 792|maumere,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=maumere,id
#
# Processing record 793|rikitea,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rikitea,pf
#
# Processing record 794|carnarvon,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=carnarvon,au
#
# Processing record 795|belmonte,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=belmonte,br
#
# Processing record 796|domoni,km
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=domoni,km
#
# Processing record 797|ascension,bo
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ascension,bo
#
# City not found. Skipping...
#
# Processing record 798|hambantota,lk
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hambantota,lk
#
# Processing record 799|malanje,ao
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=malanje,ao
#
# Processing record 800|sattenapalle,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sattenapalle,in
#
# -----------------------------
# Data Minning Completed
# -----------------------------

# %%
# Create an "extracts" object to get the various parameter required to form the weather data table
summary = ["name","sys.country","dt","coord.lat", "coord.lon","main.temp_max","main.humidity","wind.speed","clouds.all"]

# Create a Pandas DataFrame with the results
data = [response(*summary) for response in weather_data]
column_names = ["City","Country","Date","Latitude", "Longitude","Temperature","Humidity","Wind speed","Cloudliness"]
weather_data = pd.DataFrame(data, columns=column_names)

weather_data.head()
# Out:
#           City Country        Date  Latitude  Longitude  Temperature  \
# 0     Hanzhong      CN  1517108517     33.08     107.03        23.75
# 1       Jiexiu      CN  1517108517     37.02     111.92        17.36
# 2      Dauriya      RU  1517108517     49.93     116.85        -5.05
# 3  Henties Bay      NA  1517108518    -22.12      14.28        62.36
# 4      Jaragua      BR  1517104800    -15.76     -49.33        69.80
#
#    Humidity  Wind speed  Cloudliness
# 0        79        2.91           88
# 1        45        3.91            8
# 2        63       13.80           36
# 3       100        1.90           76
# 4        88        2.24           40

# %%
# Save the result to a csv file
weather_data.to_csv("Output/Weather_Data.csv")
# Count of the data in the dataframe
weather_data.count()
# Out:
# City           711
# Country        711
# Date           711
# Latitude       711
# Longitude      711
# Temperature    711
# Humidity       711
# Wind speed     711
# Cloudliness    711
# dtype: int64

# %%
# Creating a function to set the properties of the graph
def plotprops(xlabelname,ylabelname,xlimits):
    plt.xlabel(xlabelname)
    plt.ylabel(ylabelname)
    plt.xlim(xlimits)
    plt.title("%s vs %s (%s/%s/%s)"%(xlabelname,ylabelname,now.month,now.day,now.year),fontsize=14)
    plt.grid(True)

# %% [markdown]
# Latitude vs Temperature Plot

# %%
# Latitude vs Temperature(F)
plt.scatter(x=weather_data["Latitude"],y=weather_data["Temperature"],facecolors="blue",edgecolors="black")
plotprops("Latitude","Max. Temperature(°F)",[-90,90])
plt.savefig("Output/City Latitude vs Temperature.jpeg")
plt.show()

# %% [markdown]
# Latitude vs. Humidity Plot

# %%
# Latitude vs Humidity

plt.scatter(x=weather_data["Latitude"],y=weather_data["Humidity"],facecolors="blue",edgecolors="black")
plotprops("Latitude","Humidity(%)",[-90,90])
plt.savefig("Output/City Latitude vs Humidity.jpeg")
plt.show()

# %% [markdown]
# Latitude vs. Cloudiness Plot

# %%
# Latitude vs Cloudliness  

plt.scatter(x=weather_data["Latitude"],y=weather_data["Cloudliness"],facecolors="blue",edgecolors="black")
plotprops("Latitude","Cloudiness(%)",[-90,90])
plt.savefig("Output/City Latitude vs Cloudiness.jpeg")
plt.show()

# %% [markdown]
# Latitude vs Wind Speed

# %%
# Latitude vs Wind Speed  

plt.scatter(x=weather_data["Latitude"],y=weather_data["Wind speed"],facecolors="blue",edgecolors="black")
plotprops("Latitude","Wind speed(mph)",[-90,90])
plt.savefig("Output/City Latitude vs Wind speed.jpeg")
plt.show()
